# %% [markdown]
# ## Questão 1

# %% [markdown]
# ### a)
#
# | $v$ | $\delta(v)$ |
# | --- | - |
# | $A$ | 2 |
# | $B$ | 2 |
# | $C$ | 3 |
# | $P$ | 2 |
# | $D$ | 3 |
# | $E$ | 2 |
# | $F$ | 2 |

# %% [markdown]
# ### b)
#
# $$C(A) = \frac{N-1}{\sum_u{d(v,u)}} = \frac{6}{1+1+2+3+4+4} = \frac{6}{15} = \frac{2}{5}$$
#
# $$C(C) = \frac{6}{1+1+1+2+3+3} = \frac{6}{11}$$
#
# $$C(P) = \frac{6}{2+2+1+1+2+2} = \frac{6}{10} = \frac{3}{5}$$
#
# Pela simetria do grafo podemos notar que $C(A) = C(B) = C(E) = C(F)$ e $C(C) = C(D)$
#
# | $v$ | $B(v)$ |
# | --- | -------------- |
# | $A$ | $\frac{2}{5}$  |
# | $B$ | $\frac{2}{5}$  |
# | $C$ | $\frac{6}{11}$ |
# | $P$ | $\frac{6}{10}$ |
# | $D$ | $\frac{6}{11}$ |
# | $E$ | $\frac{2}{5}$  |
# | $F$ | $\frac{2}{5}$  |

# %% [markdown]
# ### c)
#
# $B(v)$ é dado pela quantidade de caminhos mínimos de vértices $i,j \neq v; \ i \neq j$ que passam por v sobre a quantidade total de arestas caminhos entre vértices $i,j; \ i \neq j$.
#
# Para calcular $B(v)$ denotaremos por $S$ o conjunto de caminhos mínimos que passa por $v$ e por $N$ o conjunto de caminhos mínimos que não passa por $v$, sendo assim $B(v) = \frac{|S|}{|S|+|N|}$.
#
# Como os únicos vértices ligados a $A$ são $B$ e $C$, e existe uma aresta direta $(B,C)$ sabemos que a centralidade de intermediação de $A$ é zero. Pela simetria do grafo o mesmo vale para $B, E \ \text{e} \ F$, portanto,  $B(A)=B(B)=B(E)=B(F)=0$
#
# Para $C$ temos: $S = \{(AP),(AD),(AE),(AF),(BP),(BD),(BE),(BF)\}$ e $N = \{(AB),(PD),(PE),(PF),(DE),(DF),(EF)\}$
#
# Como $|S| = 8$ e $|N| = 7$ temos $B(C) = \frac{8}{8+7} = \frac{8}{15}$ e por simetria $B(D) = B(C) = \frac{8}{15}$
#
# Para $P$ temos: $S = \{(AD),(AE),(AF),(BD),(BE),(BF),(CD),(CE),(CF)\}$ e $N = \{(AB),(AC),(BC),(DE),(DF),(EF)$, portanto podemos calcular $B(P) = \frac{|S|}{|S|+|N|} = \frac{9}{15} = \frac{3}{5}$
#
# | $v$ | $B(v)$ |
# | --- | -------------- |
# | $A$ | 0 |
# | $B$ | 0  |
# | $C$ | $\frac{8}{15}$ |
# | $P$ | $\frac{3}{5}$ |
# | $D$ | $\frac{8}{15}$ |
# | $E$ | 0  |
# | $F$ | 0  |

# %% [markdown]
# ### d)
#
# | $\delta(v)$ | $C(V)$ | $B(V)$ |
# | - | - | - |
# | C | P | P |
# | D | C | C |
# | A | D | D |
# | B | A | A |
# | P | B | B |
# | E | E | E |
# | F | F | F |

# %% [markdown]
# ### e)
#
# Suponha uma modelagem em grafos das ruas de uma região de forma que as ruas são vértices e existe uma aresta entre duas ruas $a,b$ se e somente se é possível ir da rua $a$ para a rua $b$.
#
# Sendo assim qualquer ponte é um exemplo de vértice assim, visto que uma ponte só tem intersecção com 2 ruas, e portanto tem grau 2, no entanto a betweeness é muito grande, por ser a única forma de acessar a outra cidade.
